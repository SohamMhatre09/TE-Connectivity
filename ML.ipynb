# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the data
data = pd.read_csv(r'C:\Users\itsoh\Downloads\TE\TE\monthly_encoded_full_data.csv')
# Out:
# C:\Users\itsoh\AppData\Local\Temp\ipykernel_32920\2658535008.py:6: DtypeWarning: Columns (24,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(r'C:\Users\itsoh\Downloads\TE\TE\monthly_encoded_full_data.csv')

# %%
data.head()
# Out:
#           Date Created        Date Modified      Status  DCT Ind  \
# 0  2024-04-11 09:01:30  2024-04-11 10:30:44  Registered      0.0
# 1  2024-04-20 09:01:32  2024-04-20 09:01:32  Registered      NaN
# 2  2024-04-18 21:01:38  2024-04-18 21:01:38  Registered      NaN
# 3  2024-03-31 09:01:32  2024-03-31 10:36:05  Registered      0.0
# 4  2024-03-31 09:01:37  2024-03-31 10:34:35  Registered      0.0
#
#   SFDC Interest Tag ID  ZZ -Activity Rating  ZZ - Activity Created Date  \
# 0                  NaN                  NaN                         NaN
# 1                  NaN                  NaN                         NaN
# 2                  NaN                  NaN                         NaN
# 3                  NaN                  NaN                         NaN
# 4                  NaN                  NaN                         NaN
#
#    Eloqua Synch Date SFDC Campaign ID SFDC Campaign Member ID  ...  \
# 0                NaN  701E0000000j3dK         00vE000000V6yvy  ...
# ...

# %%
data["Inquiry Status"].value_counts()
# Out:
# Inquiry Status
# Sales Rejected     149394
# Sales Qualified      3385
# Name: count, dtype: int64
